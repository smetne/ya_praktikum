# %% [markdown]
# <div class="alert alert-block alert-info">
# Привет! Меня зовут Аня и я представляю тебе мой проект по исследованию объявлений по продаже квартир :)
#
# Я очень надеюсь, что мне удалось все сделать правильно, больше всего я переживаю за выводы, потому что, как мне кажется, я не очень хорошо читаю графики.
#
# Очень жду твоих замечаний и комментариев!
# </div>

# %% [markdown]
# Привет, Аня!
#
# Меня зовут Павел Сурков, я буду делать ревью самостоятельной работы. Если ты не против, давай будем общаться на «ты».
#
# Понял тебя, постараюсь дать более подробные комментарии в части выводов :)
#
# Для удобства я использовал цвета в своих комментариях.
# <div class="alert alert-success">✔️ Так я отметил удачные и элегантные решения, на которые можно опираться в будущих проектах.</div>
# <div class="alert alert-danger">❌ Так отмечены ошибки, после их добработки проект будет принят.</div>
# <div class="alert alert-warning">⚠️ А такие комментарии ты можешь учесть при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> Например так ты можешь оформить свои комментарии.</div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Определим-и-посмотрим-на-пропущенные-значения" data-toc-modified-id="Определим-и-посмотрим-на-пропущенные-значения-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Определим и посмотрим на пропущенные значения</a></span></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типа данных</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-параметры:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Исследуем-параметры:-площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Исследуем параметры: площадь, цена, число комнат, высота потолков</a></span></li><li><span><a href="#Изучим-время-продажи-квартиры" data-toc-modified-id="Изучим-время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучим время продажи квартиры</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span></li><li><span><a href="#Проанализируем-10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="Проанализируем-10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проанализируем 10 населённых пунктов с наибольшим числом объявлений.</a></span></li><li><span><a href="#Изучим-предложения-квартир-в-Санкт-Петербурге" data-toc-modified-id="Изучим-предложения-квартир-в-Санкт-Петербурге-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучим предложения квартир в Санкт-Петербурге</a></span></li><li><span><a href="#Рассмотрим-сегмент-квартир-в-центре" data-toc-modified-id="Рассмотрим-сегмент-квартир-в-центре-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Рассмотрим сегмент квартир в центре</a></span></li><li><span><a href="#Сравнение-выводов-по-квартирам-в-центре-и-общих-выводов-по-всему-городу" data-toc-modified-id="Сравнение-выводов-по-квартирам-в-центре-и-общих-выводов-по-всему-городу-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Сравнение выводов по квартирам в центре и общих выводов по всему городу</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
# !pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.3 MB 2.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('mode.chained_assignment', None)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Датафрейм состоит из 22 колонок и 23699 строк.
# Пропуски есть в 14 колонках.
# Много данных типа float64.

# %% [markdown]
# **Описание данных**
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах (м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Данные загружены верно. Хорошая практика — добавлять описание данных в первый раздел. Так неподготовленному человеку будет проще составить представление о данных.
#
# Для большого количества параметров можно использовать data.describe().T - "T" транспонирует таблицы в pandas.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Спасибо за подсказку транспонировать таблицу, сделала :)
#
# Совершенно из головы вылетело, что надо описать данные,
# для меня-то они уже описаны Практикумом в превью проекта, исправляюсь!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b> Вдруг в будущем понадобится, с описанием будет проще вспомнить)
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Определим и посмотрим на пропущенные значения

# %% [markdown]
# **- число балконов**

# %%
data['balcony'].isna().sum()
# Out:
# 11519

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# *Очень большое количество пропусков. Скорее всего, пропуски в этом столбце означают, что балконов нет, поэтому заменим на 0.*

# %% [markdown]
# **- апартаменты**

# %%
data['is_apartment'].isna().sum()
# Out:
# 20924

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# *Очень большое количество пропусков. Предположим, пропуски в этом столбце означают, что объект недвижимости не относится к апартаментам, поэтому заменим на False.*

# %% [markdown]
# **- название населённого пункта**

# %%
data['locality_name'].isna().sum()
# Out:
# 49

# %%
data = data.dropna(subset = ['locality_name'])

# %% [markdown]
# *Данные маленькие, при этом отсутсвует очень важный для анализа показатель - название населенного пункта, заменить нельзя, проще удалить.*

# %% [markdown]
# **- расстояние до ближайшего аэропорта в метрах (м)**

# %%
data['airports_nearest'].isna().sum()
# Out:
# 5534

# %% [markdown]
# **- расстояние до центра города (м)**

# %%
data['cityCenters_nearest'].isna().sum()
# Out:
# 5511

# %% [markdown]
# **- число парков в радиусе 3 км**

# %%
data['parks_around3000'].isna().sum()
# Out:
# 5510

# %% [markdown]
# **- число водоёмов в радиусе 3 км**

# %%
data['ponds_around3000'].isna().sum()
# Out:
# 5510

# %% [markdown]
# *Пропуски в числе парков в том же количетсве, что и в числе водоемов, и в расстоянии до центра (за исключением 1 записи), также у близкого к этому кол-ва объектов отсутсвует информация о расстоянии до аэропорта. Проверим, одни и те же это объекты или разные.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Хорошая гипотеза 👍 Навык поиска таких закономерностей в данных может быть очень полезным в работе аналитика.
#
# </div>

# %%
data[(data['parks_around3000'].isna()) & (data['ponds_around3000'].isna()) & 
         (data['cityCenters_nearest'].isna()) & (data['airports_nearest'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# *Выявили 5510 объектов, по которым отсутствует информация по паркам и водоемам в радиусе 3 км, также отсутсвует информация о расстоянии до центра города и ближайшего аэропорта. Такие данные должны быть получены автоматически на основе картографических данных, это странно, что их нет. Такой большой объем пропусков нельзя заполнить без риска исказить результаты исследования, избавляться от них тоже не стоит, так как эти объекты содержат другие важные для исследования данные, оставим эти пропуски.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно. На практике можно поискать зависимости между названиями населенных пунктов и потерянными признаками, но в этой работе приоритет в исследовании данных.
#
# </div>

# %% [markdown]
# **- высота потолков**

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9160

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data.groupby('floors_total')['ceiling_height'].transform('median'))

# %% [markdown]
# *Довольно большой объем данных не содержит информации о высоте потолков, удалять нельзя. Попробуем заменить пропуски медианным значением с привязкой к этажности дома (будем исходить из предположения, что дома с одинаковым кол-вом этажей, скорее всего относятся к одному проекту, соответсвенно, имеют схожие параметры).*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно, хорошая гипотеза
#
# </div>

# %%
data['ceiling_height'].isna().sum()
# Out:
# 77

# %% [markdown]
# *Осталось всего 77 пропусков*

# %% [markdown]
# **- этажность**

# %%
data['floors_total'].isna().sum()
# Out:
# 85

# %%
data[data['floors_total'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237               4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457               4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671               4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757              5   3600000.0        39.0  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22542             5   8500000.0        63.5  2017-05-24T00:00:00      2
# 22656             4   4574160.0        64.5  2017-04-02T00:00:00      2
# 22808             0  14569263.0       110.4  2016-11-20T00:00:00      3
# 23590             0  21187872.0       123.3  2017-04-25T00:00:00      3
# 23658             6   3063600.0        43.8  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data = data.dropna(subset = ['floors_total'])

# %% [markdown]
# *85 в масштабе всего датафрейма - очень маленький набор данных, да и этажность - не такой уж важный для исследования параметр, удалим их.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно, такие небольшие потери не должны оказать большое влияние на результат.
#
# </div>

# %% [markdown]
# **- жилая площадь в квадратных метрах (м²)**

# %%
data['living_area'].isna().sum()
# Out:
# 1865

# %% [markdown]
# *Небольшой объем данных не содержит информации о метраже жилой площади, заменим пропуски на медианное значение с привязкой к округленной общей площади.*

# %%
data['living_area'] = data['living_area'].fillna(data.groupby(data['total_area'].round())['living_area'].transform('median'))

# %%
data['living_area'].isna().sum()
# Out:
# 14

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# **- площадь кухни в квадратных метрах (м²)**

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2222

# %% [markdown]
# *Небольшой объем данных не содержит информации о метраже кухни, может быть, потому что это студия?*

# %%
data['studio'].value_counts()
# Out:
# False    23419
# True       146
# Name: studio, dtype: int64

# %%
data[(data['studio'] == True) & (data['kitchen_area'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00  2017-03-30T00:00:00      0
# 440               8   2480000.0       27.11  2018-03-12T00:00:00      0
# 608               2   1850000.0       25.00  2019-02-20T00:00:00      0
# 697              12   2500000.0       24.10  2017-12-01T00:00:00      0
# 716               5   1500000.0       17.00  2017-06-07T00:00:00      0
# ...             ...         ...         ...                  ...    ...
# 22867             8   3090000.0       30.00  2017-12-17T00:00:00      0
# 22877             2   4280000.0       28.00  2017-10-26T00:00:00      0
# 23210             7   3200000.0       26.00  2017-09-01T00:00:00      0
# 23554            15   3350000.0       26.00  2018-09-07T00:00:00      0
# 23637             8   2350000.0       26.00  2018-06-26T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# *У всех студий отсутсвует метраж кухни, это логично, но не объясняет все остальные пропуски.*

# %%
data['open_plan'].value_counts()
# Out:
# False    23498
# True        67
# Name: open_plan, dtype: int64

# %%
data[(data['open_plan'] == True) & (data['kitchen_area'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 349               4   2320000.0        25.0  2017-09-27T00:00:00      0
# 508               0   3375000.0        34.4  2017-03-28T00:00:00      0
# 780               9   2600000.0        26.1  2018-02-20T00:00:00      0
# 839              14   1900000.0        35.0  2017-04-14T00:00:00      0
# 946               5   2200000.0        23.0  2016-09-27T00:00:00      0
# ...             ...         ...         ...                  ...    ...
# 21299            13   2450000.0        28.5  2017-11-22T00:00:00      0
# 21628             9   3900000.0        34.0  2017-03-18T00:00:00      0
# 22573             8   2250000.0        24.0  2017-09-28T00:00:00      0
# 23442             0   2500000.0        27.7  2017-09-28T00:00:00      0
# 23592            10   1450000.0        29.0  2017-11-11T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# *Свободная планировка объясняет еще 67 пропусков, но остается еще много.*

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data.groupby(data['total_area'].round())['kitchen_area'].transform('median'))

# %% [markdown]
# *Заменим пропуски на медианное значение с привязкой к округленной общей площади.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# **- расстояние до ближайшего парка (м)**

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15535

# %% [markdown]
# *Очень много пропусков, лучше оставить их как есть*

# %% [markdown]
# **- расстояние до ближайшего водоема (м)**

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14529

# %% [markdown]
# *Очень много пропусков, лучше оставить их как есть*

# %% [markdown]
# **-сколько дней было размещено объявление**

# %%
data['days_exposition'].isna().sum()
# Out:
# 3171

# %% [markdown]
# *Пропуски в более чем 10% данных, допустим, пропуски связаны с тем, что объект еще продается, тогда пропуски стоит оставить.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Когда предположение можно проверить с помощью имеющихся данных, я всегда рекомендую это делать. Например в этом случае можно посмотреть даты размещений объявлений с незаполненным признаком дней размещения.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Хм, я ниже отсортировала все объявления с пропусками в днях размещения по дате размещений.
# Есть как свежие объявления, так и объявления с 2014 года - наврядли так долго продаются квартиры, это какая-то ошибка. Забыли снять объявление? В любом случа, в очищенные данные эти объявления уже не попали, так что, ничего страшного, что они остались в таком виде :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b> Какая-то часть будет в каждом году, но большинство можно определить с помощью гистограммы :)
#
# </div>

# %%
data[data['days_exposition'].isna()].sort_values(by = 'first_day_exposition')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3291              8   8200000.0        52.5  2014-11-27T00:00:00      1
# 3873              7  20100000.0       117.6  2014-11-27T00:00:00      3
# 15857             6  25000000.0       145.2  2014-11-27T00:00:00      3
# 6922             17  29999000.0       133.5  2014-12-08T00:00:00      3
# 11055             3   8200000.0        47.1  2014-12-09T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 17872             3   4650000.0        34.8  2019-05-03T00:00:00      1
# 12343            12   2890000.0        48.8  2019-05-03T00:00:00      2
# 12380             9   3900000.0        35.6  2019-05-03T00:00:00      1
# 15072             5   1400000.0        34.0  2019-05-03T00:00:00      1
# 15881             9   2100000.0        35.8  2019-05-03T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# **- количество комнат**

# %%
data[(data['rooms'] == 0)]['rooms'].count()
# Out:
# 194

# %% [markdown]
# *194 квартиры с 0 комнат, возможно, это студии или свободная планировка?*

# %%
data[(data['rooms'] == 0) & ((data['studio'] == True) | (data['open_plan'] == True))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00  2017-03-30T00:00:00      0
# 349               4   2320000.0       25.00  2017-09-27T00:00:00      0
# 440               8   2480000.0       27.11  2018-03-12T00:00:00      0
# 508               0   3375000.0       34.40  2017-03-28T00:00:00      0
# 608               2   1850000.0       25.00  2019-02-20T00:00:00      0
# ...             ...         ...         ...                  ...    ...
# 23210             7   3200000.0       26.00  2017-09-01T00:00:00      0
# 23442             0   2500000.0       27.70  2017-09-28T00:00:00      0
# 23554            15   3350000.0       26.00  2018-09-07T00:00:00      0
# 23592            10   1450000.0       29.00  2017-11-11T00:00:00      0
# 23637             8   2350000.0       26.00  2018-06-26T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# *194 объекта, относящихся к студиям или свободной планировке, с 0 количеством комнат. Значит, можно заменить кол-во комнат на 1.*

# %%
data.loc[(data.rooms == 0), 'rooms'] = 1

# %%
data[(data['rooms'] == 0) & ((data['studio'] == True) | (data['open_plan'] == True))]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# *Квартир с 0 комнат не осталось. Проверим, нет ли кварттир-студий или квартир со свободной планировкой
# больше чем с 1 комнатой, что было бы ошибкой.*

# %%
data[(data['rooms'] > 1) & ((data['studio'] == True) | (data['open_plan'] == True))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8861             13   5500000.0        64.5  2015-11-13T00:00:00      3
# 12760             0   3350000.0        51.0  2015-01-22T00:00:00      2
# 14017            13   3990000.0        59.0  2016-03-29T00:00:00      3
# 17783             3  48763000.0       157.0  2016-04-01T00:00:00      5
# 19796             1  12000000.0        97.2  2016-04-05T00:00:00      4
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 8861             3.00           5.0         48.0      2         False  ...
# 12760            2.50          12.0         30.0     10         False  ...
# 14017            2.50           9.0         37.6      3         False  ...
# 17783            2.75          11.0        104.2      5         False  ...
# 19796            3.35           5.0         71.3      2         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# *Заменим занчения на 1.*

# %%
data.loc[(data['rooms'] > 1) & ((data['studio'] == True) | (data['open_plan'] == True)), 'rooms'] = 1

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Крутой уровень погружения в исследование и работа с логической индексацией 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Ура! Спасибо!
# </div>

# %% [markdown]
# ### Изменение типа данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23564 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23551 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23542 non-null  float64
#  13  balcony               23565 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# *Заменим тип данных в столбце с датами публикации.*

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# *Заменим тип данных в кол-ве этажей в доме, кол-ве балконов, парков, водоемов на целочисленный, так как эти данные не могут быть выражены дробным значением.*

# %%
data['floors_total'] = data['floors_total'].round().astype('Int64')
data['balcony'] = data['balcony'].round().astype('int64')

# %%
data['parks_around3000'] = data['parks_around3000'].round().astype('Int64')

# %%
data['ponds_around3000'] = data['ponds_around3000'].round().astype('Int64')

# %% [markdown]
# *Округлим кол-во дней*

# %%
data['days_exposition'] = data['days_exposition'].round()

# %% [markdown]
# *Округилим данные в столбцах с расстояниями, нам не нужна точность до сантиметра*

# %%
data['airports_nearest'] = data['airports_nearest'].round()
#data['airports_nearest'] = data['airports_nearest'].astype('Int64')

# %%
data['cityCenters_nearest'] = data['cityCenters_nearest'].round()
#data['cityCenters_nearest'] = data['cityCenters_nearest'].astype('Int64')

# %%
data['parks_nearest'] = data['parks_nearest'].round()
#data['parks_nearest'] = data['parks_nearest'].astype('Int64')

# %%
data['ponds_nearest'] = data['ponds_nearest'].round()
#data['ponds_nearest'] = data['ponds_nearest'].astype('Int64')

# %% [markdown]
# *Заменим тип данных о последней цене на целочисленный и отобразим цены в тыс. для удобства*

# %%
data['last_price'] = data['last_price'] / 1000

# %%
data['last_price'] = data['last_price'].astype('int64')

# %% [markdown]
# *Округлим высоту потолка до 2 знаков после запятой.*

# %%
data['ceiling_height'] = data['ceiling_height'].round(2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23564 non-null  float64
#  6   floors_total          23565 non-null  Int64
#  7   living_area           23551 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23542 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# *Типы данных успешно заменены*

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Верно. Но зачем округлять данные. Округление на большом количестве строк может приводить к потерям информации. Лучше округлять непосредственно вывод на экран с помощью pd.set_option('display.float_format', '{:.2f}'.format) или df.style.format()
#
# [Статья на хабре про оформление таблиц](https://habr.com/ru/post/521894/)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Утащила статью в закладки, очень интресно, особенно работа с цветом в самой таблице!
#
# Я вообще думала преобразовать чать данных с расстоянием в целочисленные значения, но графики с Int64 у меня отказывались строиться, поэтому я просто округлила, чтобы было удобнее данные смотреть. Я пока не буду в этом проекте менять эту часть. Но к следующему спринту изучу эту статью и попрактикуюсь :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b> 👍
#
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# *Добавим цену за квадратный метр*

# %%
data['price_meter'] = (data['last_price'] / data['total_area']).round().astype('int64')

# %% [markdown]
# *Добавим день недели, месяц и год публикации объявления*

# %%
data['day_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).weekday

# %%
data['month_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).month

# %%
data['year_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %% [markdown]
# *Добавим столбец с этажом квартиры (по категориям)*

# %%
def floor_categorized(row):
    floor = row['floor']
    floor_total = row['floors_total']
    if floor == 1:
        return 'первый'
    if floor == floor_total:
        return 'последний'
    return 'другой'

data['floor_category'] = data.apply(floor_categorized, axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# *Добавим соотношение жилой и общей площади.*

# %%
data['living_ratio'] = data['living_area'] / data['total_area']

# %% [markdown]
# *Добавим отношение площади кухни к общей.*

# %%
data['kitchen_ratio'] = data['kitchen_area'] / data['total_area']

# %% [markdown]
# *Все столбцы добавлены успешно*

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследуем параметры: площадь, цена, число комнат, высота потолков

# %% [markdown]
# Общая площадь

# %%
data['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# *Минимум 12 квадратов общей площади, гараж?
# Максимум 900 квадратов - целый дворец, не иначе. Что-то тут не так.*

# %%
data.hist(column='total_area', range=(0, 300), bins=30)
plt.show()

# %%
plt.ylim(0, 200) 
data.boxplot('total_area')
plt.show()

# %% [markdown]
# *Пик на площади в районе 50 кв.м, похоже на правду.
# Квартиры общей площадью более 115 кв.м и менее 24 кв.м уже достаточно редкое явление.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно, медиана чуть больше 50, границы наблюдаемых значений 115 сверху и 15 снизу. Квартира в 15 кв.м. выглядит подозрительно, можно увеличить экспертно, можно отсечь какой-то процент с помощью метода .quantile(). Более точные значения можно найти только имея опыт работы с доменом. То есть если знать, насколько маленькие студии сейчас в ходу в Петербурге и насколько большие объединенные коммуналки нередкость.
#
# [Документация quantile](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.quantile.html)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Спасибо, попробую разобраться с квантилями.
# </div>

# %%
data_clear = data.query('24 <= total_area <= 110')

# %% [markdown]
# Цена

# %% [markdown]
# *последняя*

# %%
data_clear['last_price'].describe()
# Out:
# count    22071.000000
# mean      5269.432015
# std       3276.283819
# min         12.000000
# 25%       3390.000000
# 50%       4500.000000
# 75%       6267.500000
# max      53000.000000
# Name: last_price, dtype: float64

# %%
data_clear.hist(column='last_price', range=(0, 60000), bins=30)
plt.show()

# %%
plt.ylim(0, 15000) 
data_clear.boxplot('last_price')
plt.show()

# %% [markdown]
# *Все, что дороже 10.4 млн, кажется выбросом. В существование квартир дешевле 1 млн рублей совершенно не верится.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %%
data_clear = data_clear.query('1000 < last_price <= 10400')

# %% [markdown]
# *за квадратный метр*

# %%
data_clear['price_meter'].describe()
# Out:
# count    20460.000000
# mean        91.846628
# std         28.028648
# min         13.000000
# 25%         75.000000
# 50%         92.000000
# 75%        108.000000
# max        312.000000
# Name: price_meter, dtype: float64

# %%
data_clear.hist(column='price_meter', range=(0, 270), bins=30)
plt.show()

# %%
plt.ylim(0, 300) 
data_clear.boxplot('price_meter')
plt.show()

# %% [markdown]
# *Первый график, похожий на колокол! Выбросы есть ниже 25 тыс. и выше 160 тыс.*

# %%
data_clear = data_clear.query('25 <= price_meter <= 160')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# Число комнат

# %%
data_clear['rooms'].describe()
# Out:
# count    20135.000000
# mean         1.913534
# std          0.865164
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %%
data_clear.hist(column='rooms', range=(0, 10), bins=10)
plt.show()

# %%
data_clear.boxplot('rooms')
plt.show()

# %% [markdown]
# *Самое распространенное число комнат - 1-2, правдоподобно. Более 6 комнат - уже редкость.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %%
data_clear = data_clear.query('rooms <= 6')

# %% [markdown]
# Высота потолков

# %%
data_clear['ceiling_height'].describe()
# Out:
# count    20134.000000
# mean         2.700524
# std          0.798769
# min          1.000000
# 25%          2.550000
# 50%          2.600000
# 75%          2.750000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
data_clear.hist(column='ceiling_height', range=(2, 5), bins=10)
plt.show()

# %%
plt.ylim(0, 4) 
data_clear.boxplot('ceiling_height')
plt.show()

# %% [markdown]
# *Самая распространенная высота потолков в районе 2,6 - вполне ожидаемо. Потолки выше 3,10 и ниже 2,25 - редкое явление.*

# %%
data_clear = data_clear.query('2.25 <= ceiling_height <= 3.10')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# ### Изучим время продажи квартиры

# %%
data_clear['days_exposition'].describe()
# Out:
# count    17275.000000
# mean       169.138929
# std        206.686863
# min          1.000000
# 25%         43.000000
# 50%         90.000000
# 75%        214.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# *Продажа за 1 день,как и за 4 года выглядит весьма сомнительно.*

# %%
data_clear.hist(column='days_exposition', bins=30)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Можно использовать больше корзин с целью обнаружить локальные пики
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Действительно, теперь есть пик в районе 50 дней!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b> 👍
# </div>

# %%
plt.ylim(0, 600)
data_clear.boxplot('days_exposition')
plt.show()

# %% [markdown]
# *После 470 дней видны выбросы. Меньше чем за месяц квартиру продать сложно, с учетом всех показов, согласования и заключения договора и оформления документов.*

# %%
data_clear = data_clear.query('30 <= days_exposition <= 470')

# %% [markdown]
# *Посмотрим на среднее и медиану.*

# %%
data_sell = data_clear.pivot_table(index='year_exposition', values='days_exposition', aggfunc=['mean', 'median'])

# %%
data_sell.columns = ['mean_exposition', 'median_exposition']

# %%
data_sell
# Out:
#                  mean_exposition  median_exposition
# year_exposition
# 2015                  334.648094              333.0
# 2016                  199.048327              169.0
# 2017                  152.538404              115.0
# 2018                  112.592385               85.0
# 2019                   53.227041               48.0

# %% [markdown]
# *Данные за 2016-2018 год не слишком чисты, т.к. большая разница между средним и медианой.*

# %%
data_sell.plot()
plt.show()

# %% [markdown]
# *С каждым годом квартиры продаются все быстрее. В среднем, можно считать, что "нормальные" сроки продажи - от 1,5 до 7 месяцев.*

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Кажется, что слишком большие значения показателей для такого короткого временного интервала, из-за чего однозначно сложно сказать, стали продаваться квартиры быстрее, или это искажение в данных. В выборку попадают только проданные квартиры и чем ближе к последней дате выгрузки - тем быстрее они будут проданы.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# И правда, я не подумала, что раз тут только проданные квартиры, то чем ближе к последней дате выгрузки - тем быстрее они будут проданы, тогда предположение не совсем верно.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> Здорово, что ты сохранила очищенный датасет в отдельную переменную. Перед оценкой зависимостей можно сравнить его размер с изначальным и сделать вывод о принятом методе очистки.
#
# </div>

# %%
round(data_clear.shape[0]/data.shape[0]*100, 2)
# Out:
# 53.84

# %% [markdown]
# <div class="alert alert-block alert-info">
# После очистки данных осталось 54%, наверное, это не очень хорошо и надо лучше обрабатывать данные перед анализом.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b> Кажется что это довольно строго. Можно было бы расширить границы анализа.
#
# </div>

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %% [markdown]
# Построим матрицу диаграмм рассеяния  и посмотрим, как влияют на стоимость квартиры общая площадь, число комнат и удалённость от центра.

# %%
data_cityCenters = data_clear.dropna(subset =['cityCenters_nearest']) 
#создаем датафрейм без пропусков в данных об удаленности от центра

# %%
data_matrix = data_cityCenters[['total_area', 'last_price','rooms','cityCenters_nearest']]

# %%
pd.plotting.scatter_matrix(data_matrix, figsize=(12, 12))
plt.show()

# %%
data_matrix.corr()
# Out:
#                      total_area  last_price     rooms  cityCenters_nearest
# total_area             1.000000    0.790615  0.796076            -0.079171
# last_price             0.790615    1.000000  0.512616            -0.307354
# rooms                  0.796076    0.512616  1.000000            -0.053440
# cityCenters_nearest   -0.079171   -0.307354 -0.053440             1.000000

# %% [markdown]
#  * 1) Цена увеличивается пропорционально увеличению общей площади.
#  * 2) Чем больше общая площадь, тем больше комнат.
#  * 3) Из пунктов 1, 2 и диаграммы вырисовывается слабая прямая связь между кол-вом комнат и ценой.
#  * 4) Очень слабая обратная связь между удаленностью от центра и ценой: чем ближе к центру, тем выше цена.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно. Из матрицы хорошо видна зависимость площади и цены, и резкий рост минимальной стоимости квартир в самом центре.
#
# </div>

# %% [markdown]
# Посмотрим, влияет ли этаж на цену.

# %%
data_floor = data_clear.groupby('floor_category')['price_meter'].mean().sort_values()
data_floor
# Out:
# floor_category
# первый       77.959071
# последний    81.731459
# другой       93.191918
# Name: price_meter, dtype: float64

# %%
data_floor.plot(kind='bar')
plt.show()

# %% [markdown]
# *Самые дешевые квартиры на первом и последнем этажах.*

# %% [markdown]
# Зависит ли цена от даты размещения объявления?

# %% [markdown]
# *От дня недели?*

# %%
data_day = data_clear.groupby('day_exposition')['price_meter'].median()
data_day
# Out:
# day_exposition
# 0    91.0
# 1    91.0
# 2    91.0
# 3    91.0
# 4    90.0
# 5    89.0
# 6    90.0
# Name: price_meter, dtype: float64

# %%
data_day.plot()
plt.show()

# %% [markdown]
# *Разница в районе 1-2 тысяч рублей, в субботу дешевле всего. В целом, день недели публикации объявления не сильно вляет на цену за квадратный метр.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# *От месяца?*

# %%
data_month = data_clear.groupby('month_exposition')['price_meter'].median()
data_month
# Out:
# month_exposition
# 1     91.0
# 2     90.0
# 3     90.0
# 4     89.0
# 5     90.0
# 6     89.0
# 7     92.5
# 8     93.0
# 9     92.0
# 10    91.0
# 11    91.0
# 12    89.0
# Name: price_meter, dtype: float64

# %%
data_month.plot()
plt.show()

# %% [markdown]
# *Наблюдается разница в 1-4 тысячи рублей, самые дорогие объявления публикуются с июля по сентябрь.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# *От года?*

# %%
data_year = data_clear.groupby('year_exposition')['price_meter'].median()
data_year
# Out:
# year_exposition
# 2015     88.0
# 2016     89.0
# 2017     89.0
# 2018     93.0
# 2019    101.0
# Name: price_meter, dtype: float64

# %%
data_year.plot()
plt.show()

# %% [markdown]
# *С 2017 года наблюдается резкий рост цен.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# ### Проанализируем 10 населённых пунктов с наибольшим числом объявлений.

# %%
top_locality = data_clear['locality_name'].value_counts().head(10)

# %%
top_locality
# Out:
# Санкт-Петербург      7870
# посёлок Мурино        350
# посёлок Шушары        308
# Всеволожск            259
# посёлок Парголово     230
# Колпино               212
# Пушкин                207
# деревня Кудрово       206
# Гатчина               199
# Выборг                153
# Name: locality_name, dtype: int64

# %%
data_locality = data_clear[data_clear['locality_name'].isin(top_locality.index)]

# %%
data_locality.groupby('locality_name')['price_meter'].mean().sort_values(ascending = False)
# Out:
# locality_name
# Санкт-Петербург      101.979543
# Пушкин                98.608696
# деревня Кудрово       92.752427
# посёлок Парголово     88.891304
# посёлок Мурино        85.188571
# посёлок Шушары        77.561688
# Колпино               74.179245
# Гатчина               68.040201
# Всеволожск            66.741313
# Выборг                56.490196
# Name: price_meter, dtype: float64

# %% [markdown]
# *Разброс цен за квадратный метр по 10 городам с самым большим кол-вом объявлений составляет от 56,5 до 101,9 тысяч рублей. Самый дорогой город - Санкт-Петербург, на втором месте Пушкин. Дешевле всего квадратный метр стоит в Выборге.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# ### Изучим предложения квартир в Санкт-Петербурге

# %%
data_spb = data_cityCenters[data_cityCenters['locality_name'] == 'Санкт-Петербург']

# %%
data_spb['cityCenters_nearest_km'] = (data_spb['cityCenters_nearest']/1000).round()

# %%
data_spb['cityCenters_nearest_km'].describe()
# Out:
# count    7861.000000
# mean       12.813255
# std         4.248871
# min         0.000000
# 25%        11.000000
# 50%        13.000000
# 75%        15.000000
# max        29.000000
# Name: cityCenters_nearest_km, dtype: float64

# %%
data_spb_mean = data_spb.groupby('cityCenters_nearest_km')['price_meter'].mean()

# %%
data_spb_mean.plot()

# %% [markdown]
# *Чем дальше от центра, тем дешевле квадратный метр. Центральной зоной можно считать 20 км.*

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера :</b> 20км кажется довольно большим радиусом для центра :) Определение границы с помощью графика сделано верно - с помощью резкого изменения тренда.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# У меня нет своего представления о том, какой приемлемый радиус может быть для центра :(
# </div>

# %% [markdown]
# ### Рассмотрим сегмент квартир в центре

# %%
data_spb_center = data_spb.query('cityCenters_nearest_km <= 20')

# %% [markdown]
# Исследуем параметры: площадь, цена, число комнат, высота потолков

# %% [markdown]
# Площадь

# %%
data_spb_center['total_area'].describe()
# Out:
# count    7539.000000
# mean       52.184062
# std        16.471968
# min        24.000000
# 25%        40.000000
# 50%        48.700000
# 75%        62.300000
# max       110.000000
# Name: total_area, dtype: float64

# %%
data_spb_center.hist(column='total_area', range=(0, 300), bins=30)
plt.show()

# %%
plt.ylim(0, 125) 
data_spb_center.boxplot('total_area')
plt.show()

# %% [markdown]
# *Пик на площади в районе 50 кв.м, похоже на правду.
# Квартиры общей площадью более 95 кв.м и менее 24 кв.м уже достаточно редкое явление.*

# %% [markdown]
# Цена

# %%
data_spb_center['last_price'].describe()
# Out:
# count     7539.000000
# mean      5272.672768
# std       1727.461817
# min       1846.000000
# 25%       3975.000000
# 50%       4870.000000
# 75%       6300.000000
# max      10400.000000
# Name: last_price, dtype: float64

# %%
data_spb_center.hist(column='last_price', range=(0, 20000), bins=30)
plt.show()

# %%
plt.ylim(0, 12000) 
data_spb_center.boxplot('last_price')
plt.show()

# %% [markdown]
# *Все, что дороже 9.8 млн, кажется выбросом. Минимальная стоимость близка к 2 млн - возможно.*

# %% [markdown]
# Число комнат

# %%
data_spb_center['rooms'].describe()
# Out:
# count    7539.000000
# mean        1.911792
# std         0.858861
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: rooms, dtype: float64

# %%
data_spb_center.hist(column='rooms', range=(0, 7), bins=10)
plt.show()

# %%
data_spb_center.boxplot('rooms')
plt.show()

# %% [markdown]
# *Самое распространенное число комнат - 1-2, правдоподобно. Более 5 комнат - уже редкость.*

# %% [markdown]
# Высота потолков

# %%
data_spb_center['ceiling_height'].describe()
# Out:
# count    7539.000000
# mean        2.660951
# std         0.144514
# min         2.300000
# 25%         2.550000
# 50%         2.650000
# 75%         2.750000
# max         3.100000
# Name: ceiling_height, dtype: float64

# %%
data_spb_center.hist(column='ceiling_height', range=(2, 5), bins=10)
plt.show()

# %%
plt.ylim(0, 4) 
data_spb_center.boxplot('ceiling_height')
plt.show()

# %% [markdown]
# *Самая распространенная высота потолков в районе 2,6. Потолки выше 3,10 и ниже 2,25 - редкое явление.*

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Верно
#
# </div>

# %% [markdown]
# Какие факторы больше всего влияют на стоимость квартиры?

# %% [markdown]
# Построим матрицу диаграмм рассеяния  и посмотрим, как влияют на стоимость квартиры общая площадь, число комнат и удалённость от центра.

# %%
data_matrix_spb = data_spb_center[['total_area', 'last_price','rooms','cityCenters_nearest']]

# %%
pd.plotting.scatter_matrix(data_matrix_spb, figsize=(12, 12))
plt.show()

# %%
data_matrix_spb.corr()
# Out:
#                      total_area  last_price     rooms  cityCenters_nearest
# total_area             1.000000    0.816080  0.786367            -0.181392
# last_price             0.816080    1.000000  0.505878            -0.301360
# rooms                  0.786367    0.505878  1.000000            -0.124883
# cityCenters_nearest   -0.181392   -0.301360 -0.124883             1.000000

# %% [markdown]
#  * 1) Цена увеличивается пропорционально увеличению общей площади.
#  * 2) Чем больше общая площадь, тем больше комнат.
#  * 3) Из пунктов 1, 2 и диаграммы вырисовывается слабая прямая связь между кол-вом комнат и ценой.
#  * 4) Очень слабая обратная связь между удаленностью от центра и ценой: чем дальше от центра, тем ниже цена.

# %% [markdown]
# Посмотрим, влияет ли этаж на цену.

# %%
data_floor_spb = data_spb_center.groupby('floor_category')['price_meter'].mean().sort_values()
data_floor_spb
# Out:
# floor_category
# первый        92.759150
# последний     99.246429
# другой       104.359877
# Name: price_meter, dtype: float64

# %%
data_floor_spb.plot(kind='bar')
plt.show()

# %% [markdown]
# *Самые дешевые квартиры на первом этаже.*

# %% [markdown]
# Зависит ли цена от даты размещения объявления?

# %% [markdown]
# *От дня недели?*

# %%
data_day_spb = data_spb_center.groupby('day_exposition')['price_meter'].median()
data_day_spb
# Out:
# day_exposition
# 0    100.5
# 1    100.0
# 2    101.0
# 3    101.0
# 4     99.0
# 5    101.0
# 6    101.0
# Name: price_meter, dtype: float64

# %%
data_day_spb.plot()
plt.show()

# %% [markdown]
# *Разница в районе 1-2 тысяч рублей, в пятницу дешевле всего.*

# %% [markdown]
# *От месяца?*

# %%
data_month_spb = data_spb_center.groupby('month_exposition')['price_meter'].median()
data_month_spb
# Out:
# month_exposition
# 1     102.0
# 2     100.0
# 3     101.0
# 4      98.0
# 5      99.0
# 6     100.0
# 7     100.0
# 8     102.0
# 9     102.0
# 10     99.0
# 11    100.0
# 12    101.0
# Name: price_meter, dtype: float64

# %%
data_month_spb.plot()
plt.show()

# %% [markdown]
# *Наблюдается разница в 1-4 тысячи рублей, самые дешевые объявления публикуются в апреле и октябре.*

# %% [markdown]
# *От года?*

# %%
data_year_spb = data_spb_center.groupby('year_exposition')['price_meter'].median()
data_year_spb
# Out:
# year_exposition
# 2015     95.0
# 2016     97.0
# 2017     98.0
# 2018    103.0
# 2019    109.0
# Name: price_meter, dtype: float64

# %%
data_year_spb.plot()
plt.show()

# %% [markdown]
# *С 2017 года наблюдается резкий рост цен.*

# %% [markdown]
# ### Сравнение выводов по квартирам в центре и общих выводов по всему городу

# %% [markdown]
# Больше всего на рынке представлено квартир площадью около 50 квадратных метров с 1-2 комнатами, это утверждение справедливо как для центра, так и для всего города.
#
# Мингимальная стоимость квартир в центре начинается с 2 млн. По остальному городу стоимость ближе к 1 млн. Ориентировочная предельная стоимость в районе 9,8 млн для центра и 10,4 для остального города.
#
# Высота потолков варьируется от 2,6 до 3,10 как в центре, так и по всему городу.
#
# Цена увеличивается пропорционально увеличению общей площади, чем больше общая площадь, тем больше комнат, чем дальше от центра, тем ниже цена.
#
# Самые дешевые квартиры на первом и последнем этажах по городу, в центре самые дешевые квартиры на первом этаже, на последнем этаже занимают скорее среднюю позицию по стоимости. Самые дорогие, как и во всем городе - в категории "другие".
#
# День публикации объявления влияет на цену с размахом в 1-2 тысячи рублей, в субботу публикуются самые дешевые объявления для всего города, для центра в пятницу.
#
# Разница в ценах в зависимости от месяца публикации составляет от 1 до 4 тысяч рублей, при этом для всего города самые "дорогие" месяцы с июля по сентябрь. Для центра самые дешевые объявления публикуются в апреле и октябре.
#
# С 2017 года наблюдается резкий рост цен как в центре, так и во всем городе.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Подробный логичный вывод. Интересная зависимость, минимальная цена в центре выше, но не максимальная.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В этом исследовании были изучены данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Задача исследования — установить параметры, по которым можно определять рыночную стоимость объектов недвижимости.
#
# Предоставленные данные были обработаны, где была возможность - заполнили пропуски и заменили тип данных. Также убрали совсем редкие и выбивающиеся значения. Было выявлено довольно большое количество пропусков данных, которые должны заполняться автоматически на основе картографических данных, следует обратить на это внимание и выяснить, почему эти данные не заполняются.
#
# В данные были добавлены:
# * цена квадратного метра;
# * день недели, месяц и год публикации объявления;
# * этаж квартиры; варианты — первый, последний, другой;
# * соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# Были изучены следующие параметры: площадь, цена, число комнат, высота потолков.
# Также было изучено время продажи квартир, в ходе исследования выяснили, что обычно время продажи находится в пределах от 1,5 до 7 месяцев.
#
# Выяснили, что на стоимость квартиры влияют:
# общая площадь - чем больше, тем дороже;
# число комнат - чем больше площадь, тем больше комнат, тем выше цена;
# удаленность от центра - чем дальше, тем дешевле;
# этаж, на котором расположена квартира - самые дорогие не на первом и не на последнем.
#
# Также есть небольшая зависимость цены за квадратный метр от дня недели и месяца:
# разница 1-2 тысячи рублей, в субботу публикуются самые дешевые объявления для всего города, для центра в пятницу;
# разница 1-4 тысячи рублей, для всего города самые "дорогие" месяцы с июля по сентябрь, для центра самые дешевые объявления публикуются в апреле и октябре.
#
# С 2017 года наблюдается резкий рост цен на жилье.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера :</b> Все здорово, есть центральная мысль, отношение к проделанной работы к цели исследования. Также в вывод вынесены опорные пункты исследования.
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий ревьюера :</b>
#
# Мне понравилась твоя работа. Очень подробно разобрана как часть с пропусками, так и другая с определением выпадающих значений. Есть описание логики принятия решений, комментарии в коде. Есть гипотезы о природе задач, логичные выводы с информацией о принимаемых решениях. В части оформления можно использовать больше заголовков 2 и 3 уровней, это сделает навигацию по проекту удобнее.
#
# В качестве точки роста можешь попробовать поупражняться с оформлением графиков, а вместе с оформлением и оборачиванием их в функции, чтобы не копировать весь код оформления.
#
# Возвращаю проект обратно, чтобы убедиться - все мои комментарии понятны. Если вдруг у тебя возникнут вопросы, то я с радостью отвечу на них. Также ты можешь учесть мои рекомендации и сделать свой проект еще лучше.Но я приму работу и без них, если у тебя не осталось вопросов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Спасибо за ревью, буду упражняться с оформлением графиков и таблиц! :)
# </div>
