# %% [markdown]
# # Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+
#
# Несколько прошлых месяцев бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нужно разобраться в причинах этой ситуации.
#
# В распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Следует изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# **Описание данных**
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %%
visits = pd.read_csv('visits_info_short.csv')
orders = pd.read_csv('orders_info_short.csv')
costs = pd.read_csv('costs_info_short.csv')

# %% [markdown]
# Приведем названия столбцов к змеиному регистру и изменим тип данных у столбцов с датой и временем. Проверим на наличие дубликатов.

# %%
visits.rename(columns={'User Id': 'User_Id', 'Session Start': 'Session_Start', 'Session End': 'Session_End'}, inplace=True)
visits.columns = visits.columns.str.lower()
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.duplicated().sum()
# Out:
# 0

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
orders.rename(columns={'User Id': 'User_Id', 'Event Dt': 'Event_Dt'}, inplace=True)
orders.columns = orders.columns.str.lower()
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
orders.duplicated().sum()
# Out:
# 0

# %%
costs.columns = costs.columns.str.lower()
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
costs.duplicated().sum()
# Out:
# 0

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
for i in (visits, orders, costs):
    print(round((i.isna().mean()*100),2))
# Out:
# user_id          0.0
# region           0.0
# device           0.0
# channel          0.0
# session_start    0.0
# session_end      0.0
# dtype: float64
# user_id     0.0
# event_dt    0.0
# revenue     0.0
# dtype: float64
# dt         0.0
# channel    0.0
# costs      0.0
# dtype: float64

# %% [markdown]
# **Вывод**
#
# Наименования колонок не соответсвовали принятому стилю описания, поэтому все наименования были приведены к змеиному регистру через rename(). Данные о дате и времени конвертировали в формат datetime с помощью to_datetime().
#
# Дубликатов и пропусков не обнаружено.

# %% [markdown]
# ## Зададим функции для расчета и анализа LTV, ROI, удержания и конверсии

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Построим профили пользователей

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальные и максимальные даты привлечения.

# %%
print(f"Минимальная дата привлечения {profiles['dt'].min()}")
print(f"Максимальная дата привлечения {profiles['dt'].max()}")
# Out:
# Минимальная дата привлечения 2019-05-01
# Максимальная дата привлечения 2019-10-27

# %% [markdown]
# ### Страны

# %% [markdown]
# Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?

# %%
country = (
    profiles.groupby('region')
    .agg({'user_id': 'nunique', 'payer':['sum', 'mean']})
    .sort_values(by=('payer', 'mean'), ascending=False)
)
country.columns = ['Уникальных пользователей', 'Платящих пользователей', '% платящих']
country.style.format({'Платящих пользователей': '{:.0f}', '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_5125ec04_9fab_11ec_a21e_02420a3952b4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Уникальных пользователей</th>        <th class="col_heading level0 col1" >Платящих пользователей</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5125ec04_9fab_11ec_a21e_02420a3952b4level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_5125ec04_9fab_11ec_a21e_02420a3952b4row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_5125ec04_9fab_11ec_a21e_02420a3952b4row0_col1" class="data row0 col1" >6902</td>
# ...

# %% [markdown]
# Больше всего посетителей из США, второе место делят Великобритания и Франция, в хвосте Германия. По количеству платящих пользователей картина чуть другая: в топе США, на втором месте Германия, Франция и Великобритания делят третье место. При этом из всех стран платящих пользователей приходит очень мало.

# %% [markdown]
# ### Устройства

# %% [markdown]
# Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?

# %%
device = (
    profiles.groupby('device')
    .agg({'user_id': 'nunique', 'payer':['sum', 'mean']})
    .sort_values(by=('payer', 'mean'), ascending=False)
)
device.columns = ['Уникальных пользователей', 'Платящих пользователей', '% платящих']
device.style.format({'Платящих пользователей': '{:.0f}', '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_512a7094_9fab_11ec_a21e_02420a3952b4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Уникальных пользователей</th>        <th class="col_heading level0 col1" >Платящих пользователей</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_512a7094_9fab_11ec_a21e_02420a3952b4level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_512a7094_9fab_11ec_a21e_02420a3952b4row0_col0" class="data row0 col0" >30042</td>
#                         <td id="T_512a7094_9fab_11ec_a21e_02420a3952b4row0_col1" class="data row0 col1" >1912</td>
# ...

# %% [markdown]
# Пользователи используют устройства Mac, iPhone, Android и PC. Больше всего пользователей с iPhone, на втором месте Android, в хвосте Mac и PC, то есть, пользователей больше всего с мобильных устройств. При этом платящие пользователи заходят чаще всего с устройств Mac и iPhone (то есть пользователи IOS), далее по убыванию идут Android и PC.

# %% [markdown]
# ### Рекламные каналы

# %% [markdown]
# По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
channel = (
    profiles.groupby('channel')
    .agg({'user_id': 'nunique', 'payer':['sum', 'mean']})
    .sort_values(by=('payer', 'mean'), ascending=False)
)
channel.columns = ['Уникальных пользователей', 'Платящих пользователей', '% платящих']
channel.style.format({'Платящих пользователей': '{:.0f}', '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_512ebf46_9fab_11ec_a21e_02420a3952b4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Уникальных пользователей</th>        <th class="col_heading level0 col1" >Платящих пользователей</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_512ebf46_9fab_11ec_a21e_02420a3952b4level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_512ebf46_9fab_11ec_a21e_02420a3952b4row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_512ebf46_9fab_11ec_a21e_02420a3952b4row0_col1" class="data row0 col1" >3557</td>
# ...

# %%
print(f"Топ-5 каналов по привлечению платящих пользователей: {channel.index.values.tolist()[:5]}")
# Out:
# Топ-5 каналов по привлечению платящих пользователей: ['FaceBoom', 'AdNonSense', 'lambdaMediaAds', 'TipTop', 'RocketSuperAds']

# %% [markdown]
# **Вывод**

# %% [markdown]
# С большим отрывом по количеству уникальных пользователей и платящих пользователей лидирует США. Чаще всего пользователи приходят с мобильных устройств, при этом платящие пользователи чаще заходят с устройств на платформе IOS. Больше всего пользователей приходит через каналы FaceBoom, AdNonSense, lambdaMediaAds, TipTop, RocketSuperAds.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# Сколько всего денег потратили?

# %%
print(f"За период с 1 мая по 27 октября 2019 года потрачено на привлечение {round(costs['costs'].sum(), 2)}$")
# Out:
# За период с 1 мая по 27 октября 2019 года потрачено на привлечение 105497.3$

# %% [markdown]
# ### Расходы на источники

# %% [markdown]
# Сколько денег потратили на каждый источник?

# %%
cost_per_channel = (
    costs.groupby('channel')
    .agg({'costs' : 'sum'})
    .reset_index()
)

# %%
plt.figure(figsize=(13, 5))

cost_per_channel = cost_per_channel.sort_values(['costs'], ascending=False).reset_index(drop=True)

sns.barplot(
    x="costs", 
    y="channel", 
    data=cost_per_channel
)
plt.xlabel('Потрачено, $')
plt.ylabel('Канал привлечения')
plt.title('Расходы на привлечение пользователей с 1 мая по 27 октября 2019 года')
plt.show()

# %% [markdown]
# Больше всего денег вложили в TipTop и FaceBoom, на остальные источники потрачено значительно меньше.

# %% [markdown]
# ### Расходы по времени

# %% [markdown]
# Динамика расходов по времени.

# %%
cost_per_month = costs
cost_per_month['month'] = pd.to_datetime(costs['dt']).dt.month

# %%
cost_per_month = costs.groupby('month').agg({'costs' : 'sum'}).sort_values(by='month', ascending=False)

# %%
plt.figure(figsize=(13, 5))
plt.plot(cost_per_month)
plt.xlabel('Месяц')
plt.ylabel('Потрачено, $')
plt.title('Расходы на привлечение пользователей с мая по октябрь 2019 года')
plt.show()

# %% [markdown]
# График показывает рост расходов на привлечение вплоть до сентября. При этом наиболее резкое увеличение трат фиксируется с мая по июнь и с июля по август.

# %% [markdown]
# ### CAC

# %% [markdown]
# Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Уберем органический трафик

# %%
profiles = profiles.query('channel != "organic"')

# %%
print(f"Средний САС на одного пользователя для всего проекта {round(profiles['acquisition_cost'].mean(), 2)}")
# Out:
# Средний САС на одного пользователя для всего проекта 1.13

# %%
cac_per_channel = (
    round(profiles.groupby('channel')['acquisition_cost']
          .mean().sort_values(ascending=False), 2).reset_index()
)

# %%
plt.figure(figsize=(13, 5))

cac_per_channel = cac_per_channel.sort_values(['acquisition_cost'], ascending=False).reset_index(drop=True)

sns.barplot(
    x="acquisition_cost", 
    y="channel", 
    data=cac_per_channel
)
plt.xlabel('Потрачено, $')
plt.ylabel('Канал привлечения')
plt.title('Расходы на привлечение одного покупателя с 1 мая по 27 октября 2019 года')
plt.show()

# %%
cac_per_channel.T
# Out:
#                        0         1           2               3  \
# channel           TipTop  FaceBoom  AdNonSense  lambdaMediaAds
# acquisition_cost     2.8      1.11        1.01            0.72
#
#                                4               5                   6        7  \
# channel           WahooNetBanner  RocketSuperAds  OppleCreativeMedia  YRabbit
# acquisition_cost             0.6            0.41                0.25     0.22
#
#                              8        9
# channel           MediaTornado  LeapBob
# acquisition_cost          0.22     0.21

# %% [markdown]
# Самые дорогие пользователи приходят с канала TipTop - 2.80 $ за человека.

# %% [markdown]
# ### Вывод

# %% [markdown]
# За период с 1 мая по 27 октября 2019 года затраты на маркетинг составили 105497.3 у.е.
# Больше всего денег вложили в TipTop и FaceBoom, на остальные источники потрачено значительно меньше.
# Рост расходов на привлечение зафиксирован с мая по сентябрь. При этом наиболее резкое увеличение трат фиксируется с мая по июнь и с июля по август.
# Самые дорогие пользователи приходят с канала TipTop - 2.80 у.е. за человека, при том, что средний САС составляет 1.13 у.е. за пользователя.

# %% [markdown]
# ## Окупаемость рекламы для привлечения пользователей

# %% [markdown]
# ### Общая окупаемость рекламы

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - Реклама не окупается. ROI к концу недели около 80%. При этом по графику динамики ROI видно, что окупаемость начала стремительно падать в мае, в середине мая наблюдаем незначительный рост, а с середины июня ROI стабильно снижается
# - с мая по июнь резко растет стоимость привлечения пользователей, с ростом стоимости привлечения пользователей почти зеркально падает ROI
# - LTV относительно стабилен

# %% [markdown]
# Исходя из полученных данных можно предположить, что был неудачно закуплен трафик. Попробуем разобраться.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['device'])
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - Стабильно окупается только реклама для пользователей PC, среди которых, как мы выяснили ранее, меньше всего платящих пользователей. И то, окупаемость продолжает падать.
# - Реклама для Android не окупается, не смотря на увеличение трат на привлечение в мае.
# - Привлечение юзеров устройств на платформе IOS не окупается, при этом, стоимость их привлечения в июне выросла намного больше, чем у остальных.
# - У всех пользователей падение окупаемости по времени совпадает с увеличением стоимости привлечения (август для PC и май для остальных).

# %% [markdown]
# **Посмотрим на конверсию и удержание**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# Пользователи Mac и iPhone дают стабильно хорошую конверсию, с июня она выросла. PC-юзеры сильно отстают, но при этом единственные, кто пока окупаются. Android дает конверсию повыше PC, но его также штормит.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# До августа лучше всего удерживались платящие пользователи PC, при этом удержание у всех категорий устройств очень слабое.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['region'])
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Кажется, проблема обнаружена - в мае закуплена очень дорогая реклама на аудиторию США, которая совсем не окупается!

# %% [markdown]
# **Посмотрим на конверсию и удержание**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Очень хорошая конверсия у пользователей из США. С июня она возросла, у остальных стран конверсия с июня заметно упала.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# Удержание платящих пользователей из США самое низкое и самое стабильное. У остальных стран размах удержания платящих пользователей намного шире. У Германии и Франции удержание платящих пользователей эпизодическое. У пользователей из Великобритании проседает удержание с августа по октябрь.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel'])
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# - lambdaMediaAds и TipTop имеют самый высокий показатель LTV среди остальных каналов
# - качетсво клиентов с канала lambdaMediaAds заметно выше в динамике, особенно с июня по июль
# - стоимость привлечения пользователей через канал TipTop с мая стремительно растет, RocketSuperAds падает, стоимость остальных каналов остается без изменений
# - каналы TipTop, AdNonSense и FaceBoom стабильно не окупаются
# - ТОП-5 каналов по окупаемости: YRabbit, MediaTornado, lambdaMediaAds, LeapBob, RocketSuperAds
# - в летние месяцы наблюдается сильный рост окупаемости у канала YRabbit
# - в осенние месяцы рост окупаемости показывают каналы RocketSuperAds и MediaTornado

# %% [markdown]
# **Посмотрим на конверсию и удержание**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# - хорошую конверсию дают: FaceBoom, AdNonSense, lambdaMediaAds, TipTop, RocketSuperAds
# - динамика конверсии относительно стабильна у всех каналов, кроме lambdaMediaAds

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# - очень плохое удержание платящих пользователей у FaceBoom и AdNonSense
# - стабильное удержание платящих пользователей у каналов FaceBoom, TipTop

# %% [markdown]
# ### Исследование проблемных мест

# %% [markdown]
# Ранее мы выяснили, что имеются проблемы с окупаемостью рекламы в США, а также каналов TipTop, AdNonSense и FaceBoom. Рассмотрим их детальнее.

# %%
usa = profiles.query('region == "United States"')

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    usa, orders, observation_date, horizon_days, dimensions=['channel'])
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Видим, что реклама для США в TipTop и FaceBoom не окупается, при том, что были увеличены денежные вложения в привлечение через TipTop.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    usa, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# При этом TipTop, FaceBoom и RocketSuperAds имеют самую высокую конверсию для этого региона.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    usa, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# Отметим также, что FaceBoom имеет катастрофически низкое удержание платящих пользователей. У RocketSuperAds и MediaTornado большие проблемы со стабильностью удержания.

# %%
ans = profiles.query('channel == "AdNonSense"')
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    ans, orders, observation_date, horizon_days)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Канал AdNonSense окупается только с августа по октябрь, и то, с переменным успехом.

# %% [markdown]
# ### Вывод

# %% [markdown]
# С июня реклама не окупается.
# С мая по июнь резко растет стоимость привлечения пользователей, после июня САС стабильно растет.
# LTV относительно стабилен.

# %% [markdown]
# Если смотреть на рекламу в разрезе устройств пользователей, то
#
# - стабильно окупается только реклама для пользователей PC, среди которы меньше всего платящих пользователей
# - реклама для Android и IOS не окупается, не смотря на увеличение трат на привлечение в мае.
#
# У всех пользователей падение окупаемости по времени совпадает с увеличением стоимости привлечения (август для PC и май для остальных).

# %% [markdown]
# Анализ показателей по каналам привлечения дал такие результаты
#
# - lambdaMediaAds и TipTop имеют самый высокий показатель LTV среди остальных каналов, качетсво клиентов с канала lambdaMediaAds заметно выше в динамике, особенно с июня по июль
# - стоимость привлечения пользователей через канал TipTop с мая стремительно растет, на RocketSuperAds явно сократили расходы, стоимость остальных каналов остается без изменений
# - каналы TipTop, AdNonSense и FaceBoom стабильно не окупаются
# - ТОП-5 каналов по окупаемости: YRabbit, MediaTornado, lambdaMediaAds, LeapBob, RocketSuperAds, в летние месяцы наблюдается сильный рост окупаемости у канала YRabbit, также RocketSuperAds и MediaTornado дают лучше окупаемость с началом осени
# - хорошую конверсию дают: FaceBoom, AdNonSense, lambdaMediaAds, TipTop, RocketSuperAds
# - динамика конверсии относительно стабильна у всех каналов, кроме lambdaMediaAds
#
# - стабильное удержание платящих пользователей у каналов FaceBoom и TipTop, при этом у FaceBoom и AdNonSense удержание очень низкое

# %% [markdown]
# Самая большая аудитория у приложения - в США и среди пользователей IOS. При этом с ростом расходов на привлечение этой категории пользователей окупаемость пропорционально снижается.

# %% [markdown]
# В мае закуплена очень дорогая реклама на аудиторию США, которая совсем не окупается. С июня конверсия пользователей из США возросла, но удержание самое низкое и самое стабильное из всех регионов. У остальных стран размах удержания платящих пользователей намного шире. У Германии и Франции удержание платящих пользователей эпизодическое. В Великобритании наблюдаются проблемы с удержанием пользователей с началом осени.

# %% [markdown]
# Реклама для США в TipTop и FaceBoom не окупается, при том, что в мае были увеличены денежные вложения в привлечение через TipTop.
# При этом TipTop и FaceBoom имеют самую высокую конверсию для этого региона, но FaceBoom имеет катострофически низкое удержание платящих пользователей.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Несколько прошлых месяцев бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Задача была разобраться в причинах этой ситуации.
#
# Мы проанализировали данные о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузку их покупок за этот период, а также статистику рекламных расходов. Изучили, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.

# %% [markdown]
# **Причины неэффективности привлечения пользователей**

# %% [markdown]
# В результате проведенного исследования и анализа бизнес-показателей удалось выяснить следующее:
#
# - большой отрицательный эффект на бизнес оказало увеличение расходов на привлечение пользователей США через канал TipTop, он стабильно не окупается
# - также отрицательный эффект дает закупка трафика из США через канал FaceBoom, окупаемости у канала нет
# - канал AdNonSense не дает окупаемости
# - снижены затраты на канал RocketSuperAds, хотя он дает неплохие результаты

# %% [markdown]
# **Рекомендации для отдела маркетинга**

# %% [markdown]
# - снизить расходы на TipTop
# - отказаться от канала FaceBoom в пользу других (например RocketSuperAds, MediaTornado)
# - оставить канал AdNonSense на сезонное привлечение (конец лета - осень)
# - обратить внимание на аудиторию Германии - хорошая окупаемость, но нестабильное удержание летом
# - обратить внимание на Великобританию - закупить под конец лета - начало осени траффик у AdNonSense, как вариант
# - пересмотреть политику удержания во Франции
# - самые платящие пользователи - юзеры платформы IOS, можно поработать отдельно над привлечением этой категории
